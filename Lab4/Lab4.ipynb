# %%
import pandas as pd

# %%
data = pd.read_csv("Review.csv")

# %%
data
# Out:
#                                               Review
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    punctuation_free = ""
    
    for i in text:
        print("........")
        print(i)
        if i not in string.punctuation:
            punctuation_free = punctuation_free + i
            print(punctuation_free)
            print("!!!!!!")
    return punctuation_free

# %%
data['clean_punctuation'] = data['Review'].apply(remove_punctuation)
data
# Out:
# ........
# I
# I
# !!!!!!
# ........
#
# I
# !!!!!!
# ........
# l
# I l
# !!!!!!
# ........
# i
# I li
# !!!!!!
# ........
# k
# I lik
# !!!!!!
# ........
# e
# I like
# !!!!!!
# ........
#
# I like
# !!!!!!
# ........
# t
# I like t
# !!!!!!
# ........
# h
# I like th
# !!!!!!
# ........
# i
# I like thi
# !!!!!!
# ........
# s
# I like this
# !!!!!!
# ........
#
# I like this
# !!!!!!
# ........
# b
# I like this b
# !!!!!!
# ........
# o
# I like this bo
# !!!!!!
# ........
# o
# I like this boo
# !!!!!!
# ........
# k
# I like this book
# !!!!!!
# ........
# s
# I like this books
# !!!!!!
# ........
#
# I like this books
# !!!!!!
# ........
# v
# I like this books v
# !!!!!!
# ........
# e
# I like this books ve
# !!!!!!
# ........
# r
# I like this books ver
# !!!!!!
# ........
# y
# I like this books very
# !!!!!!
# ........
#
# I like this books very
# !!!!!!
# ........
# m
# I like this books very m
# !!!!!!
# ........
# u
# I like this books very mu
# !!!!!!
# ........
# c
# I like this books very muc
# !!!!!!
# ........
# h
# I like this books very much
# !!!!!!
# ........
# !
# ........
# !
# ........
# !
# ........
#
# I like this books very much
# !!!!!!
# ........
# I
# I like this books very much I
# !!!!!!
# ........
# t
# I like this books very much It
# !!!!!!
# ........
#
# I like this books very much It
# !!!!!!
# ........
# i
# I like this books very much It i
# !!!!!!
# ........
# s
# I like this books very much It is
# !!!!!!
# ........
#
# I like this books very much It is
# !!!!!!
# ........
# V
# I like this books very much It is V
# !!!!!!
# ........
# E
# I like this books very much It is VE
# !!!!!!
# ........
# R
# I like this books very much It is VER
# !!!!!!
# ........
# Y
# I like this books very much It is VERY
# !!!!!!
# ........
#
# I like this books very much It is VERY
# !!!!!!
# ........
# I
# I like this books very much It is VERY I
# !!!!!!
# ........
# N
# I like this books very much It is VERY IN
# !!!!!!
# ........
# T
# I like this books very much It is VERY INT
# !!!!!!
# ........
# E
# I like this books very much It is VERY INTE
# !!!!!!
# ........
# R
# I like this books very much It is VERY INTER
# !!!!!!
# ........
# E
# I like this books very much It is VERY INTERE
# !!!!!!
# ........
# S
# I like this books very much It is VERY INTERES
# !!!!!!
# ........
# T
# I like this books very much It is VERY INTEREST
# !!!!!!
# ........
# I
# I like this books very much It is VERY INTERESTI
# !!!!!!
# ........
# N
# I like this books very much It is VERY INTERESTIN
# !!!!!!
# ........
# G
# I like this books very much It is VERY INTERESTING
# !!!!!!
# ........
# .
# ........
# .
# ........
# D
# D
# !!!!!!
# ........
# o
# Do
# !!!!!!
# ........
#
# Do
# !!!!!!
# ........
# n
# Do n
# !!!!!!
# ........
# o
# Do no
# !!!!!!
# ........
# t
# Do not
# !!!!!!
# ........
#
# Do not
# !!!!!!
# ........
# l
# Do not l
# !!!!!!
# ........
# i
# Do not li
# !!!!!!
# ........
# k
# Do not lik
# !!!!!!
# ........
# e
# Do not like
# !!!!!!
# ........
#
# Do not like
# !!!!!!
# ........
# t
# Do not like t
# !!!!!!
# ........
# h
# Do not like th
# !!!!!!
# ........
# i
# Do not like thi
# !!!!!!
# ........
# s
# Do not like this
# !!!!!!
# ........
#
# Do not like this
# !!!!!!
# ........
# b
# Do not like this b
# !!!!!!
# ........
# o
# Do not like this bo
# !!!!!!
# ........
# o
# Do not like this boo
# !!!!!!
# ........
# k
# Do not like this book
# !!!!!!
# ........
# .
# ........
#
# Do not like this book
# !!!!!!
# ........
# s
# Do not like this book s
# !!!!!!
# ........
# o
# Do not like this book so
# !!!!!!
# ........
#
# Do not like this book so
# !!!!!!
# ........
# b
# Do not like this book so b
# !!!!!!
# ........
# o
# Do not like this book so bo
# !!!!!!
# ........
# r
# Do not like this book so bor
# !!!!!!
# ........
# i
# Do not like this book so bori
# !!!!!!
# ........
# n
# Do not like this book so borin
# !!!!!!
# ........
# g
# Do not like this book so boring
# !!!!!!
# ........
#
# Do not like this book so boring
# !!!!!!
# ........
# 2
# Do not like this book so boring 2
# !!!!!!
# ........
# .
# ........
#
# Do not like this book so boring 2
# !!!!!!
# ........
# T
# Do not like this book so boring 2 T
# !!!!!!
# ........
# o
# Do not like this book so boring 2 To
# !!!!!!
# ........
# o
# Do not like this book so boring 2 Too
# !!!!!!
# ........
#
# Do not like this book so boring 2 Too
# !!!!!!
# ........
# l
# Do not like this book so boring 2 Too l
# !!!!!!
# ........
# e
# Do not like this book so boring 2 Too le
# !!!!!!
# ........
# n
# Do not like this book so boring 2 Too len
# !!!!!!
# ........
# g
# Do not like this book so boring 2 Too leng
# !!!!!!
# ........
# t
# Do not like this book so boring 2 Too lengt
# !!!!!!
# ........
# h
# Do not like this book so boring 2 Too length
# !!!!!!
# ........
# y
# Do not like this book so boring 2 Too lengthy
# !!!!!!
# ........
#
# Do not like this book so boring 2 Too lengthy
# !!!!!!
# ........
# :
# ........
# -
# ........
# (
#                                               Review  \
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...
#
#                                    clean_punctuation
# 0  I like this books very much It is VERY INTERES...
# 1     Do not like this book so boring 2 Too lengthy

# %%
data['clean_lower']= data['clean_punctuation'].str.lower()
data
# Out:
#                                               Review  \
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...
#
#                                    clean_punctuation  \
# 0  I like this books very much It is VERY INTERES...
# 1     Do not like this book so boring 2 Too lengthy
#
#                                          clean_lower
# 0  i like this books very much it is very interes...
# 1     do not like this book so boring 2 too lengthy

# %%
import re

# %%
def remove_numbers(text):
    return re.sub("[\d-]",'',text)

# %%
data['clean_number'] = data['clean_lower'].apply(remove_numbers)
data
# Out:
#                                               Review  \
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...
#
#                                    clean_punctuation  \
# 0  I like this books very much It is VERY INTERES...
# 1     Do not like this book so boring 2 Too lengthy
#
#                                          clean_lower  \
# 0  i like this books very much it is very interes...
# 1     do not like this book so boring 2 too lengthy
#
#                                         clean_number
# 0  i like this books very much it is very interes...
# 1      do not like this book so boring  too lengthy

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\amaknabil2001\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
data['token_data']= data['clean_number'].apply(word_tokenize)
data
# Out:
#                                               Review  \
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...
#
#                                    clean_punctuation  \
# 0  I like this books very much It is VERY INTERES...
# 1     Do not like this book so boring 2 Too lengthy
#
#                                          clean_lower  \
# 0  i like this books very much it is very interes...
# 1     do not like this book so boring 2 too lengthy
#
#                                         clean_number  \
# 0  i like this books very much it is very interes...
# 1      do not like this book so boring  too lengthy
#
#                                           token_data
# 0  [i, like, this, books, very, much, it, is, ver...
# 1  [do, not, like, this, book, so, boring, too, l...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\amaknabil2001\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(text):
    output = []
    for i in text:
        if i not in stopwords:
            output.append(i)
    return output

# %%
data['clean_xstopwords'] = data['token_data'].apply(remove_stopwords)
data
# Out:
#                                               Review  \
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...
#
#                                    clean_punctuation  \
# 0  I like this books very much It is VERY INTERES...
# 1     Do not like this book so boring 2 Too lengthy
#
#                                          clean_lower  \
# 0  i like this books very much it is very interes...
# 1     do not like this book so boring 2 too lengthy
#
#                                         clean_number  \
# 0  i like this books very much it is very interes...
# 1      do not like this book so boring  too lengthy
#
#                                           token_data  \
# 0  [i, like, this, books, very, much, it, is, ver...
# 1  [do, not, like, this, book, so, boring, too, l...
#
#                    clean_xstopwords
# 0  [like, books, much, interesting]
# 1     [like, book, boring, lengthy]

# %%
from nltk.stem.porter import PorterStemmer

# %%
porter_stemmer = PorterStemmer()

# %%
def stemming(text):
    stem_text = []
    for word in text:
        stemmed_word = porter_stemmer.stem(word)
        stem_text.append(stemmed_word)
    return stem_text

# %%
data['clean_stemmed'] = data['clean_xstopwords'].apply(stemming)
data
# Out:
#                                               Review  \
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...
#
#                                    clean_punctuation  \
# 0  I like this books very much It is VERY INTERES...
# 1     Do not like this book so boring 2 Too lengthy
#
#                                          clean_lower  \
# 0  i like this books very much it is very interes...
# 1     do not like this book so boring 2 too lengthy
#
#                                         clean_number  \
# 0  i like this books very much it is very interes...
# 1      do not like this book so boring  too lengthy
#
#                                           token_data  \
# 0  [i, like, this, books, very, much, it, is, ver...
# 1  [do, not, like, this, book, so, boring, too, l...
#
#                    clean_xstopwords                 clean_stemmed
# 0  [like, books, much, interesting]  [like, book, much, interest]
# 1     [like, book, boring, lengthy]   [like, book, bore, lengthi]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\amaknabil2001\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def lemmatizer(text):
    lemm_text = []
    for word in text:
        lemmatized_word = wordnet_lemmatizer.lemmatize(word)
        lemm_text.append(lemmatized_word)
    return lemm_text

# %%
data['clean_lemmatized1']=data['clean_xstopwords'].apply(lemmatizer)

# %%
data['clean_lemmatized2']=data['clean_stemmed'].apply(lemmatizer)
data
# Out:
#                                               Review  \
# 0  I like this books very much!!! It is VERY INTE...
# 1  Do not like this book. so boring 2. Too length...
#
#                                    clean_punctuation  \
# 0  I like this books very much It is VERY INTERES...
# 1     Do not like this book so boring 2 Too lengthy
#
#                                          clean_lower  \
# 0  i like this books very much it is very interes...
# 1     do not like this book so boring 2 too lengthy
#
#                                         clean_number  \
# 0  i like this books very much it is very interes...
# 1      do not like this book so boring  too lengthy
#
#                                           token_data  \
# 0  [i, like, this, books, very, much, it, is, ver...
# 1  [do, not, like, this, book, so, boring, too, l...
#
#                    clean_xstopwords                 clean_stemmed  \
# 0  [like, books, much, interesting]  [like, book, much, interest]
# 1     [like, book, boring, lengthy]   [like, book, bore, lengthi]
#
#                  clean_lemmatized1             clean_lemmatized2
# 0  [like, book, much, interesting]  [like, book, much, interest]
# 1    [like, book, boring, lengthy]   [like, book, bore, lengthi]

# %%
data.to_csv('clean_reviews.csv',index=False)
